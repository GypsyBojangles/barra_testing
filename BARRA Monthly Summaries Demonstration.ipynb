# %%
import datacube
from matplotlib import pyplot

# %%
# you will need a datacube confing:
config = {
    'db_hostname': 'agdcdev-db.nci.org.au',
    'db_port': 6432,
    'db_database': 'dg6911'
}
dc = datacube.Datacube(config=config)

# %%
accum_prcp = dc.load(product='accum_prcp_monthly', time='1990')
yearly_accum_prcp = accum_prcp['accum_prcp'].sum(dim='time')
yearly_accum_prcp.squeeze().plot.imshow(cmap='plasma', size=10, robust=True)

# %%
accum_prcp = dc.load(product='accum_prcp_monthly', time='1991')
yearly_accum_prcp = accum_prcp['accum_prcp'].sum(dim='time')
yearly_accum_prcp.squeeze().plot.imshow(cmap='plasma', size=10, robust=True)

# %%
accum_prcp = dc.load(product='accum_prcp_monthly', time='1992')
yearly_accum_prcp = accum_prcp['accum_prcp'].sum(dim='time')
yearly_accum_prcp.squeeze().plot.imshow(cmap='plasma', size=10, robust=True)
